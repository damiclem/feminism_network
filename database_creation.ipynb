# %%
import pandas as pd
import numpy as np

# %%
with open('data/database/tweets.csv', 'r') as file:
    tweets_data = pd.read_csv(file)
    
with open('data/database/entities.csv', 'r') as file:
    concepts_data = pd.read_csv(file)
    
with open('data/database/users.csv', 'r') as file:
    users_data = pd.read_csv(file)

# %%
#only tweets in english are kept 
tweets_data = tweets_data[tweets_data.lang == 'en']

# %%
'''
First option: join between tweets_data and concepts_data
-tweets possibly repeated in the table 
-unique row for each concept (now: just hashtags)
-keys: {index}
-in general, concepts can refer to different tweets and viceversa
'''
#join
joined_data = tweets_data.join(concepts_data.set_index('tweet_id_str'), on='id_str', how = 'left',lsuffix='_left', rsuffix='_right')
#only useful columns are kept
joined_data = joined_data.loc[:, ('id_str','created_at', 'text_left', 'text_right', 'truncated', 'retweet_count', 'type', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str')]
joined_data = joined_data.rename(columns= {'text_left' : 'text_tweet', 'text_right' : 'text_concept'}).reset_index().iloc[:,1:]
joined_data
# Out:
#                   id_str                      created_at  \
# 0    1207806578650468352  Thu Dec 19 23:35:02 +0000 2019
# 1    1207779681627447296  Thu Dec 19 21:48:10 +0000 2019
# 2    1207778191173201920  Thu Dec 19 21:42:14 +0000 2019
# 3    1207761285045260294  Thu Dec 19 20:35:04 +0000 2019
# 4    1207732772451889152  Thu Dec 19 18:41:46 +0000 2019
# 5    1207731206835576833  Thu Dec 19 18:35:32 +0000 2019
# 6    1207715986075467778  Thu Dec 19 17:35:04 +0000 2019
# 7    1207714713326510081  Thu Dec 19 17:30:00 +0000 2019
# 8    1207714713326510081  Thu Dec 19 17:30:00 +0000 2019
# 9    1207699612359749632  Thu Dec 19 16:30:00 +0000 2019
# 10   1207699612359749632  Thu Dec 19 16:30:00 +0000 2019
# 11   1207699612359749632  Thu Dec 19 16:30:00 +0000 2019
# 12   1207684513486245889  Thu Dec 19 15:30:00 +0000 2019
# 13   1207670688338890754  Thu Dec 19 14:35:04 +0000 2019
# 14   1207669414050570249  Thu Dec 19 14:30:00 +0000 2019
# 15   1207669414050570249  Thu Dec 19 14:30:00 +0000 2019
# 16   1207669414050570249  Thu Dec 19 14:30:00 +0000 2019
# 17   1207654314304368642  Thu Dec 19 13:30:00 +0000 2019
# 18   1207654314304368642  Thu Dec 19 13:30:00 +0000 2019
# 19   1207654314304368642  Thu Dec 19 13:30:00 +0000 2019
# 20   1207642847312113664  Thu Dec 19 12:44:26 +0000 2019
# 21   1207625384197533696  Thu Dec 19 11:35:02 +0000 2019
# 22   1207624115932282882  Thu Dec 19 11:30:00 +0000 2019
# 23   1207624115932282882  Thu Dec 19 11:30:00 +0000 2019
# 24   1207624115932282882  Thu Dec 19 11:30:00 +0000 2019
# 25   1207616565547544577  Thu Dec 19 11:00:00 +0000 2019
# 26   1207616565547544577  Thu Dec 19 11:00:00 +0000 2019
# 11   "Every domain of life, be it society, polity, ...
# 12   Workplaces are notorious grounds for explicit ...
# 13   "I believe we need to work together with compa...
# 14   These tweets by celebrities against #CAA are r...
# 15   These tweets by celebrities against #CAA are r...
# 16   These tweets by celebrities against #CAA are r...
# 17   "On December 16th, the road outside Chepauk St...
# 18   "On December 16th, the road outside Chepauk St...
# 19   "On December 16th, the road outside Chepauk St...
# 20   Delhi came through at Jantar Mantar today, des...
# 21   No country has achieved gender equality yet, b...
# 22   This is a tool to incite students and marginal...
# 23   This is a tool to incite students and marginal...
# 24   This is a tool to incite students and marginal...
# 25   The inclusion of #Muslims alone can bring no r...
# 26   The inclusion of #Muslims alone can bring no r...
# 27   The inclusion of #Muslims alone can bring no r...
# 28   The inclusion of #Muslims alone can bring no r...
# 29   The inclusion of #Muslims alone can bring no r...
# ..                                                 ...
# 629  Trans people are now required to be certified ...
# 630  4. On December 5, the #TransgenderBill2019 was...
# 631  Moreover, the Parliament passed the #Citizensh...
# 632  Moreover, the Parliament passed the #Citizensh...
# 633  3. The final list of #NRC released in Aug, 201...
# 634  3. The final list of #NRC released in Aug, 201...
# 635  More than 4000 people have been detained in Ka...
# 636  2. The abrogation of Article 370 of the Consti...
# 637  The arrests of 9 prominent human rights activi...
# 638  UAPA empowers officials to declare any individ...
# 639  On #HumanRightsDay , let's look at some humans...
# 640  Colonization by reducing the identity of fores...
# 641  Colonization by reducing the identity of fores...
# 642  How To Make Sure Sexting Doesn’t Turn Into Ima...
# 643  On #HumanRightsDay, our #TuesdayThoughts are t...
# 644  On #HumanRightsDay, our #TuesdayThoughts are t...
# 645  On #HumanRightsDay, our #TuesdayThoughts are t...
# 646  Happy #HumanRightsDay! \n\nWe stand with @UNHu...
# 647  Did you know about these films which talk abou...
# 648  Sulochanabai Dongre understood in the 1930s wh...
# 649  Sulochanabai Dongre understood in the 1930s wh...
# 650  RT @danwibg: Why Do Men Like Daniel Shravan, W...
# 651  RT @danwibg: Why Do Men Like Daniel Shravan, W...
# 652  RT @danwibg: How Not To Talk About ‘Women’s Sa...
# 653  RT @danwibg: Durga Devi: The Revolutionary Who...
# 654  RT @UNICEF: “We need to start treating this cr...
# 655  Want to take action for women’s rights, but ne...
# 656  15. Educate the next generation. #orangethewor...
# 657  "You are never too small to make a difference....
# 658  RT @unwomenjordan: From the right to equal pay...
#
#                      text_concept  truncated  retweet_count     type  \
# 0                    ThisHappened       True             53  hashtag
# 1                             NaN      False              0      NaN
# 2                             NaN      False            191      NaN
# 3                    WomenInSport       True             88  hashtag
# 4                             NaN      False              7      NaN
# 5                             NaN      False              6      NaN
# 6                             NaN       True           2447      NaN
# 7                        LokSabha       True              3  hashtag
# 8                 WomenInPolitics       True              3  hashtag
# 9                 IndiaRejectsCAA       True              7  hashtag
# 10                IndiaRejectsNRC       True              7  hashtag
# 11             PoliceStopViolence       True              7  hashtag
# 12                         sexism       True              0  hashtag
# 13             GenerationEquality       True             56  hashtag
# 14                            CAA       True              1  hashtag
# 15                IndiaRejectsCAA       True              1  hashtag
# 16                IndiaRejectsNRC       True              1  hashtag
# 17                   Islamophobic       True              4  hashtag
# 18        CitizenshipAmendmentAct       True              4  hashtag
# 19            IndiaRejectsCAA_NRC       True              4  hashtag
# 20                IndiaAgainstCAA       True             93  hashtag
# 21                    gendergap20       True           1424  hashtag
# 22        CitizenshipAmendmentAct       True              4  hashtag
# 23                   JantarMantar       True              4  hashtag
# 24                      IndiaGate       True              4  hashtag
# 25                        Muslims       True             10  hashtag
# 26                            CAA       True             10  hashtag
# 27                IndiaRejectsCAA       True             10  hashtag
# 28                IndiaRejectsNRC       True             10  hashtag
# 29             PoliceStopViolence       True             10  hashtag
# ..                            ...        ...            ...      ...
# 629                   HumanRights       True              2  hashtag
# 630           TransgenderBill2019       True              5  hashtag
# 631  CitizenshipAmendmentBill2019       True              3  hashtag
# 632                HumanRightsDay       True              3  hashtag
# 633                           NRC       True              5  hashtag
# 634                HumanRightsDay       True              5  hashtag
# 635                           NaN       True              3      NaN
# 636                           NaN       True              5      NaN
# 637                           NaN       True              3      NaN
# 638         HumanRightsViolations       True              4  hashtag
# 639                HumanRightsDay       True             26  hashtag
# 640                    FIIReviews       True              3  hashtag
# 641                    BookReview       True              3  hashtag
# 642                           NaN      False              2      NaN
# 643                HumanRightsDay       True             54  hashtag
# 644               TuesdayThoughts       True             54  hashtag
# 645                     FIIQuotes       True             54  hashtag
# 646                HumanRightsDay       True            743  hashtag
# 647                  UnpaidLabour       True              4  hashtag
# 648            ReproductiveRights       True              2  hashtag
# 649          IndianWomenInHistory       True              2  hashtag
# 650                           NaN      False              0      NaN
# 651                           NaN      False              0      NaN
# 652                           NaN      False              0      NaN
# 653                           NaN      False              0      NaN
# 654                           NaN      False              0      NaN
# 655                HumanRightsDay       True             77  hashtag
# 656                           NaN      False            125      NaN
# 657                           NaN      False             39      NaN
# 658                           NaN      False              0      NaN
#
#      in_reply_to_status_id_str  in_reply_to_user_id_str
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# 16                         NaN                      NaN
# 17                         NaN                      NaN
# 18                         NaN                      NaN
# 19                         NaN                      NaN
# 20                         NaN                      NaN
# 21                         NaN                      NaN
# 22                         NaN                      NaN
# 23                         NaN                      NaN
# 24                         NaN                      NaN
# 25                         NaN                      NaN
# 26                         NaN                      NaN
# 27                         NaN                      NaN
# 28                         NaN                      NaN
# 29                         NaN                      NaN
# ..                         ...                      ...
# 629               1.204309e+18             2.247560e+09
# 630               1.204309e+18             2.247560e+09
# 631               1.204309e+18             2.247560e+09
# 632               1.204309e+18             2.247560e+09
# 633               1.204308e+18             2.247560e+09
# 634               1.204308e+18             2.247560e+09
# 635               1.204308e+18             2.247560e+09
# 636               1.204308e+18             2.247560e+09
# 637               1.204308e+18             2.247560e+09
# 638               1.204308e+18             2.247560e+09
# 639                        NaN                      NaN
# 640                        NaN                      NaN
# 641                        NaN                      NaN
# 642                        NaN                      NaN
# 643                        NaN                      NaN
# 644                        NaN                      NaN
# 645                        NaN                      NaN
# 646                        NaN                      NaN
# 647                        NaN                      NaN
# 648                        NaN                      NaN
# 649                        NaN                      NaN
# 650                        NaN                      NaN
# 651                        NaN                      NaN
# 652                        NaN                      NaN
# 653                        NaN                      NaN
# 654                        NaN                      NaN
# 655                        NaN                      NaN
# 656               1.203963e+18             1.713763e+07
# 657               1.204182e+18             1.713763e+07
# 658                        NaN                      NaN
#
# [659 rows x 9 columns]

# %%
'''
Second option: concatenation of tweets_data and concepts_data
-unique row for each tweet/concept
-keys: {index, text}
-in general, hashtags refer to different tweets: id_str could contain more then one id per concept
'''
#concatenation
concat_data = pd.concat([tweets_data, concepts_data], sort = False)
#identify tweets' rows (in the type attribute)
concat_data.type.fillna('tweet', inplace=True)
#id_str and tweet_id_str columns are merged
concat_data.loc[concat_data.id_str.isna(),'id_str'] = concat_data.loc[concat_data.tweet_id_str.notna(),'tweet_id_str']
#only useful columns are kept
concat_data = concat_data.loc[:, ('id_str','created_at', 'text', 'truncated', 'retweet_count', 'type', 'in_reply_to_status_id_str', 
                          'in_reply_to_user_id_str')].reset_index().iloc[:,1:]
concat_data.head()
# Out:
#          id_str                      created_at  \
# 0  1.207807e+18  Thu Dec 19 23:35:02 +0000 2019
# 1  1.207780e+18  Thu Dec 19 21:48:10 +0000 2019
# 2  1.207778e+18  Thu Dec 19 21:42:14 +0000 2019
# 3  1.207761e+18  Thu Dec 19 20:35:04 +0000 2019
# 4  1.207733e+18  Thu Dec 19 18:41:46 +0000 2019
#
#                                                 text truncated  retweet_count  \
# 0  These events around the world prompted importa...      True           53.0
# 1  RT @wef: Women's pay equality has slipped back...     False            0.0
# 2  Happy birthday @Alyssa_Milano!🎈 Thank you for ...     False          191.0
# 3  “This is my charge to everyone:\n\nWe have to ...      True           88.0
# 4  8 Posters At The CAA Protests In Delhi That Sc...     False            7.0
#
#     type  in_reply_to_status_id_str  in_reply_to_user_id_str
# 0  tweet                        NaN                      NaN
# 1  tweet                        NaN                      NaN
# 2  tweet                        NaN                      NaN
# 3  tweet                        NaN                      NaN
# 4  tweet                        NaN                      NaN

# %%
joined_data.to_csv('data/database/joined_data.csv')
concat_data.to_csv('data/database/concat_data.csv')
