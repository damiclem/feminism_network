# %%
import pandas as pd
import numpy as np
from nltk.stem import SnowballStemmer

# %%
with open('data/database/tweets.csv', 'r') as file:
    tweets_data = pd.read_csv(file)
    
with open('data/database/entities.csv', 'r') as file:
    hashtags_data = pd.read_csv(file)
    
with open('data/database/users.csv', 'r') as file:
    users_data = pd.read_csv(file)
    
with open('data/database/words.csv', 'r') as file:
    words_data = pd.read_csv(file)
del words_data['xpos']

# %%
#tweets and hashtags data cleaning

#only tweets in english are kept 
tweets_data = tweets_data[tweets_data.lang == 'en']
#lowercase hashtags
hashtags_data.loc[:,'text'] = hashtags_data.text.str.lower()

# %%
#words_data cleaning

#relevant words selection
mask_w = ['ADJ', 'ADV', 'NOUN', 'VERB']
words_data = words_data.loc[words_data.upos.isin(mask_w),:]

#words stemming 
stemmer = SnowballStemmer("english")
words_data.loc[:,'text'] = words_data.text.apply(stemmer.stem)

#lowercase words
words_data.loc[:,'text'] = words_data.text.str.lower()

#deletion of concepts already stored as hashtags
hashtags = set(hashtags_data.text.values)
words_data = words_data.loc[~words_data.text.isin(hashtags),:]

# %%
'''
First option: join between tweets_data and hashtags_data
-tweets possibly repeated in the table 
-unique row for each concept (now: just hashtags)
-keys: {index}
-in general, concepts can refer to different tweets and viceversa
-WORDS MISSING: sentence field must be fixed to allow a join (no key to build a relationship)
'''
#join
joined_data = tweets_data.join(hashtags_data.set_index('tweet_id_str'), on='id_str', how = 'left',lsuffix='_left', rsuffix='_right')
#only useful columns are kept
joined_data = joined_data.loc[:, ('id_str','created_at', 'text_left', 'text_right', 'truncated', 'retweet_count', 'type', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str')]
joined_data = joined_data.rename(columns= {'text_left' : 'text_tweet', 'text_right' : 'text_concept'}).reset_index().iloc[:,1:]
joined_data

# %%
'''
Second option: concatenation of tweets_data and concepts_data
-unique row for each tweet/concept
-keys: {index, text}
-in general, hashtags refer to different tweets: id_str could contain more then one id per concept
-
'''
#concatenation of tweets and hashtags
concat_data = pd.concat([tweets_data, hashtags_data], sort = False)
#identify tweets' rows (in the type attribute)
concat_data.type.fillna('tweet', inplace=True)
#id_str and tweet_id_str columns are merged
concat_data.loc[concat_data.id_str.isna(),'id_str'] = concat_data.loc[concat_data.tweet_id_str.notna(),'tweet_id_str']

#concatenation of concat and words
concat_data = pd.concat([concat_data, words_data], sort = False)
#identify words' rows (in the type attribute)
concat_data.type.fillna('words', inplace=True)
#WARNING: id_str field still has to be filled (no key to build a relationship)

#only useful columns are kept
concat_data = concat_data.loc[:, ('id_str','created_at', 'text', 'truncated', 'retweet_count', 'type', 'in_reply_to_status_id_str', 
                          'in_reply_to_user_id_str')].reset_index().iloc[:,1:]
concat_data.head()
# Out:
#             id_str                      created_at  \
# 0     1.207807e+18  Thu Dec 19 23:35:02 +0000 2019
# 1     1.207780e+18  Thu Dec 19 21:48:10 +0000 2019
# 2     1.207778e+18  Thu Dec 19 21:42:14 +0000 2019
# 3     1.207761e+18  Thu Dec 19 20:35:04 +0000 2019
# 4     1.207733e+18  Thu Dec 19 18:41:46 +0000 2019
# 5     1.207731e+18  Thu Dec 19 18:35:32 +0000 2019
# 6     1.207716e+18  Thu Dec 19 17:35:04 +0000 2019
# 7     1.207715e+18  Thu Dec 19 17:30:00 +0000 2019
# 8     1.207700e+18  Thu Dec 19 16:30:00 +0000 2019
# 9     1.207685e+18  Thu Dec 19 15:30:00 +0000 2019
# 10    1.207671e+18  Thu Dec 19 14:35:04 +0000 2019
# 11    1.207669e+18  Thu Dec 19 14:30:00 +0000 2019
# 12    1.207654e+18  Thu Dec 19 13:30:00 +0000 2019
# 13    1.207643e+18  Thu Dec 19 12:44:26 +0000 2019
# 14    1.207625e+18  Thu Dec 19 11:35:02 +0000 2019
# 15    1.207624e+18  Thu Dec 19 11:30:00 +0000 2019
# 16    1.207617e+18  Thu Dec 19 11:00:00 +0000 2019
# 17    1.207594e+18  Thu Dec 19 09:30:00 +0000 2019
# 18    1.207586e+18  Thu Dec 19 08:59:50 +0000 2019
# 19    1.207580e+18  Thu Dec 19 08:35:04 +0000 2019
# 20    1.207579e+18  Thu Dec 19 08:32:04 +0000 2019
# 21    1.207579e+18  Thu Dec 19 08:32:04 +0000 2019
# 22    1.207579e+18  Thu Dec 19 08:30:00 +0000 2019
# 23    1.207579e+18  Thu Dec 19 08:28:48 +0000 2019
# 24    1.207571e+18  Thu Dec 19 07:59:07 +0000 2019
# 25    1.207564e+18  Thu Dec 19 07:30:00 +0000 2019
# 26    1.207535e+18  Thu Dec 19 05:35:02 +0000 2019
# 27    1.207518e+18  Thu Dec 19 04:30:00 +0000 2019
# 28    1.207513e+18  Thu Dec 19 04:10:07 +0000 2019
# 29    1.207508e+18  Thu Dec 19 03:46:39 +0000 2019
# ...            ...                             ...
# 1170           NaN                             NaN
# 1171           NaN                             NaN
# 1172           NaN                             NaN
# 1173           NaN                             NaN
# 1174           NaN                             NaN
# 1175           NaN                             NaN
# 1176           NaN                             NaN
# 1177           NaN                             NaN
# 1178           NaN                             NaN
# 1179           NaN                             NaN
# 1180           NaN                             NaN
# 1181           NaN                             NaN
# 1182           NaN                             NaN
# 1183           NaN                             NaN
# 1184           NaN                             NaN
# 1185           NaN                             NaN
# 1186           NaN                             NaN
# 1187           NaN                             NaN
# 1188           NaN                             NaN
# 1189           NaN                             NaN
# 1190           NaN                             NaN
# 1191           NaN                             NaN
# 1192           NaN                             NaN
# 1193           NaN                             NaN
# 1194           NaN                             NaN
# 1195           NaN                             NaN
# 1196           NaN                             NaN
# 1197           NaN                             NaN
# 1198           NaN                             NaN
# 1199           NaN                             NaN
#
#                                                    text truncated  \
# 0     These events around the world prompted importa...      True
# 1     RT @wef: Women's pay equality has slipped back...     False
# 2     Happy birthday @Alyssa_Milano!🎈 Thank you for ...     False
# 3     “This is my charge to everyone:\n\nWe have to ...      True
# 4     8 Posters At The CAA Protests In Delhi That Sc...     False
# 5     Victim Blaming In The Garb of Women Empowermen...     False
# 6     🧥\n👖\n💃\n👙\n👷‍♀️\n👗\n👩‍🎤\n🩱\n👩‍🎓\n🩲\n🤸‍♀️\n👚\n...      True
# 7     Politics and law making institutions have alwa...      True
# 8     "Every domain of life, be it society, polity, ...      True
# 9     Workplaces are notorious grounds for explicit ...      True
# 10    "I believe we need to work together with compa...      True
# 11    These tweets by celebrities against #CAA are r...      True
# 12    "On December 16th, the road outside Chepauk St...      True
# 13    Delhi came through at Jantar Mantar today, des...      True
# 14    No country has achieved gender equality yet, b...      True
# 15    This is a tool to incite students and marginal...      True
# 16    The inclusion of #Muslims alone can bring no r...      True
# 17    #Fire revolves around the relationship between...      True
# 18    RT @japna_p: Today, the FII office is shut and...     False
# 19    "The last decade was a decade of youth activis...      True
# 20    RT @The_Silly_Wonka: History is witness to how...     False
# 21    RT @japna_p: To all those who ask, "what has t...     False
# 22    In 2019, the #LokSabha Elections constituencie...      True
# 23    RT @asmitaghosh18: Protestors that have been d...     False
# 24    Update on #Delhi protests: Everyone is conveni...      True
# 25    What has #feminism got to do with the #Citizen...      True
# 26    #TBT to when the world turned orange, putting ...     False
# 27    #Sexism in workplaces is rampant in India. Her...      True
# 28    RT @FeminismInIndia: Why should you attend the...     False
# 29    RT @danwibg: Protests Erupt Against CAA And Th...     False
# ...                                                 ...       ...
# 1170                                             attend       NaN
# 1171                                               work       NaN
# 1172                                               time       NaN
# 1173                                               show       NaN
# 1174                                            display       NaN
# 1175                                            resista       NaN
# 1176                                                 rt       NaN
# 1177                                            danwibg       NaN
# 1178                                              erupt       NaN
# 1179                                            violenc       NaN
# 1180                                            student       NaN
# 1181                                                 rt       NaN
# 1182                                            danwibg       NaN
# 1183                                              photo       NaN
# 1184                                            valuabl       NaN
# 1185                                            mobilis       NaN
# 1186                                               educ       NaN
# 1187                                              peopl       NaN
# 1188                                               more       NaN
# 1189                                             celebr       NaN
# 1190                                             massiv       NaN
# 1191                                           influenc       NaN
# 1192                                               need       NaN
# 1193                                               come       NaN
# 1194                                              forth       NaN
# 1195                                               take       NaN
# 1196                                              stand       NaN
# 1197                                              share       NaN
# 1198                                             strong       NaN
# 1199                                             celebr       NaN
#
#       retweet_count   type  in_reply_to_status_id_str  in_reply_to_user_id_str
# 0              53.0  tweet                        NaN                      NaN
# 1               0.0  tweet                        NaN                      NaN
# 2             191.0  tweet                        NaN                      NaN
# 3              88.0  tweet                        NaN                      NaN
# 4               7.0  tweet                        NaN                      NaN
# 5               6.0  tweet                        NaN                      NaN
# 6            2447.0  tweet                        NaN                      NaN
# 7               3.0  tweet                        NaN                      NaN
# 8               7.0  tweet                        NaN                      NaN
# 9               0.0  tweet                        NaN                      NaN
# 10             56.0  tweet                        NaN                      NaN
# 11              1.0  tweet                        NaN                      NaN
# 12              4.0  tweet                        NaN                      NaN
# 13             93.0  tweet                        NaN                      NaN
# 14           1424.0  tweet                        NaN                      NaN
# 15              4.0  tweet                        NaN                      NaN
# 16             10.0  tweet                        NaN                      NaN
# 17              0.0  tweet                        NaN                      NaN
# 18              0.0  tweet                        NaN                      NaN
# 19            247.0  tweet                        NaN                      NaN
# 20              0.0  tweet                        NaN                      NaN
# 21              0.0  tweet                        NaN                      NaN
# 22              4.0  tweet                        NaN                      NaN
# 23              0.0  tweet                        NaN                      NaN
# 24             25.0  tweet                        NaN                      NaN
# 25              3.0  tweet                        NaN                      NaN
# 26            169.0  tweet                        NaN                      NaN
# 27              2.0  tweet                        NaN                      NaN
# 28              0.0  tweet                        NaN                      NaN
# 29              0.0  tweet                        NaN                      NaN
# ...             ...    ...                        ...                      ...
# 1170            NaN  words                        NaN                      NaN
# 1171            NaN  words                        NaN                      NaN
# 1172            NaN  words                        NaN                      NaN
# 1173            NaN  words                        NaN                      NaN
# 1174            NaN  words                        NaN                      NaN
# 1175            NaN  words                        NaN                      NaN
# 1176            NaN  words                        NaN                      NaN
# 1177            NaN  words                        NaN                      NaN
# 1178            NaN  words                        NaN                      NaN
# 1179            NaN  words                        NaN                      NaN
# 1180            NaN  words                        NaN                      NaN
# 1181            NaN  words                        NaN                      NaN
# 1182            NaN  words                        NaN                      NaN
# 1183            NaN  words                        NaN                      NaN
# 1184            NaN  words                        NaN                      NaN
# 1185            NaN  words                        NaN                      NaN
# 1186            NaN  words                        NaN                      NaN
# 1187            NaN  words                        NaN                      NaN
# 1188            NaN  words                        NaN                      NaN
# 1189            NaN  words                        NaN                      NaN
# 1190            NaN  words                        NaN                      NaN
# 1191            NaN  words                        NaN                      NaN
# 1192            NaN  words                        NaN                      NaN
# 1193            NaN  words                        NaN                      NaN
# 1194            NaN  words                        NaN                      NaN
# 1195            NaN  words                        NaN                      NaN
# 1196            NaN  words                        NaN                      NaN
# 1197            NaN  words                        NaN                      NaN
# 1198            NaN  words                        NaN                      NaN
# 1199            NaN  words                        NaN                      NaN
#
# [1200 rows x 8 columns]

# %%
joined_data.to_csv('data/database/joined_data.csv')
concat_data.to_csv('data/database/concat_data.csv')
